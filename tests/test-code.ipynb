# %%
try:
    import openmc
    print("OpenMC works! Version:", openmc.__version__)
except Exception as e:
    print("OpenMC failed to import.")
    print("Error:", e)
# Out:
# OpenMC works! Version: 0.15.3
